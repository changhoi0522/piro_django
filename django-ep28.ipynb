# %%
import requests
image_url = "http://image.fmkorea.com/files/attach/new/20160919/3655299/1132656/465417019/3261dcf0e54beeb2b6fe1b20d467c98a.jpg"
image_binary = requests.get(image_url).content

with open("flower.jpg", "wb") as f:
    f.write(image_binary)

# %%
from PIL import Image

# %%
flower_image = Image.open("flower.jpg")

# %%
flower_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=559x420 at 0x1958AF6B128>

# %%
from pilkit.processors import Thumbnail

processor = Thumbnail(width=300, height=300)

# %%
thumb_image = processor.process(flower_image)

# %%
thumb_image
# Out:
# <PIL.Image.Image image mode=RGBA size=300x300 at 0x1958C032EF0>

# %%
thumb_image.save("thumb-300x300.png")

# %%
thumb_image.save("thumb-300x300.jpg", quality=60)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\dev\piro_django_env\lib\site-packages\PIL\JpegImagePlugin.py in _save(im, fp, filename)
#     619     try:
# --> 620         rawmode = RAWMODE[im.mode]
#     621     except KeyError:
#
# KeyError: 'RGBA'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-17-de2e08a5eb47> in <module>
# ----> 1 thumb_image.save("thumb-300x300.jpg", quality=60)
#
# c:\dev\piro_django_env\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    1992
#    1993         try:
# -> 1994             save_handler(self, fp, filename)
#    1995         finally:
#    1996             # do what we can to clean up
#
# c:\dev\piro_django_env\lib\site-packages\PIL\JpegImagePlugin.py in _save(im, fp, filename)
# ...
